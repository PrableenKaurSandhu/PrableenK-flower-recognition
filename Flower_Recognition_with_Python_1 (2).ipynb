# %%
#If you are new to codding I would recommend you to search each function used to understand what exactly it does.

# %%
import os
import cv2
import numpy as np

#Encoding and Split data into Train/Test Sets
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

#Tensorflow Keras CNN Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop

#Plot Images
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_dir = '/content/drive/MyDrive/a flower data.zip (Unzipped Files)/flowers'



data = []
label = []

SIZE = 128 #Crop the image to 128x128

for folder in os.listdir(folder_dir):
    for file in os.listdir(os.path.join(folder_dir, folder)):
        if file.endswith("jpg"):
            label.append(folder)
            img = cv2.imread(os.path.join(folder_dir, folder, file)) 
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            im = cv2.resize(img_rgb, (SIZE,SIZE))
            data.append(im)
        else:
            continue

# %%
data_arr = np.array(data)
label_arr = np.array(label)

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(label_arr)
y = to_categorical(y,5)
X = data_arr/255

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
model = Sequential()
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu', input_shape = (SIZE,SIZE,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(5, activation = "softmax"))

# %%
datagen = ImageDataGenerator(
        rotation_range=20,
        zoom_range = 0.20,
        width_shift_range=0.3,
        height_shift_range=0.3,
        horizontal_flip=True,
        vertical_flip=True)

datagen.fit(X_train)

# %%
model.compile(optimizer=Adam(lr=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
batch_size=32
epochs=40
history = model.fit_generator(datagen.flow(X_train,y_train, batch_size=batch_size),
                              epochs = epochs,
                              validation_data = (X_test,y_test),
                              verbose = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/40
# 108/108 [==============================] - 29s 156ms/step - loss: 1.5283 - accuracy: 0.3113 - val_loss: 1.3099 - val_accuracy: 0.4375
# Epoch 2/40
# 108/108 [==============================] - 15s 137ms/step - loss: 1.3444 - accuracy: 0.4304 - val_loss: 1.1785 - val_accuracy: 0.5012
# Epoch 3/40
# 108/108 [==============================] - 15s 138ms/step - loss: 1.2701 - accuracy: 0.4521 - val_loss: 1.1208 - val_accuracy: 0.5347
# Epoch 4/40
# 108/108 [==============================] - 16s 151ms/step - loss: 1.2205 - accuracy: 0.4929 - val_loss: 1.1406 - val_accuracy: 0.5301
# Epoch 5/40
# 108/108 [==============================] - 17s 160ms/step - loss: 1.1599 - accuracy: 0.5277 - val_loss: 1.0586 - val_accuracy: 0.5741
# Epoch 6/40
# 108/108 [==============================] - 15s 137ms/step - loss: 1.1497 - accuracy: 0.5262 - val_loss: 1.0683 - val_accuracy: 0.5799
# Epoch 7/40
# 108/108 [==============================] - 15s 137ms/step - loss: 1.1018 - accuracy: 0.5685 - val_loss: 0.9732 - val_accuracy: 0.6204
# Epoch 8/40
# 108/108 [==============================] - 15s 136ms/step - loss: 1.0794 - accuracy: 0.5676 - val_loss: 0.9322 - val_accuracy: 0.6262
# Epoch 9/40
# 108/108 [==============================] - 15s 140ms/step - loss: 1.0441 - accuracy: 0.5948 - val_loss: 0.9299 - val_accuracy: 0.6424
# Epoch 10/40
# 108/108 [==============================] - 15s 138ms/step - loss: 1.0332 - accuracy: 0.5998 - val_loss: 0.9362 - val_accuracy: 0.6285
# Epoch 11/40
# 108/108 [==============================] - 15s 139ms/step - loss: 1.0111 - accuracy: 0.6111 - val_loss: 0.8957 - val_accuracy: 0.6435
# Epoch 12/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.9976 - accuracy: 0.6218 - val_loss: 0.9594 - val_accuracy: 0.6273
# Epoch 13/40
# 108/108 [==============================] - 15s 139ms/step - loss: 0.9827 - accuracy: 0.6198 - val_loss: 0.8661 - val_accuracy: 0.6539
# Epoch 14/40
# 108/108 [==============================] - 15s 140ms/step - loss: 0.9649 - accuracy: 0.6374 - val_loss: 0.9010 - val_accuracy: 0.6354
# Epoch 15/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.9525 - accuracy: 0.6360 - val_loss: 0.8777 - val_accuracy: 0.6690
# Epoch 16/40
# 108/108 [==============================] - 16s 143ms/step - loss: 0.9407 - accuracy: 0.6441 - val_loss: 0.7986 - val_accuracy: 0.6979
# Epoch 17/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.9223 - accuracy: 0.6513 - val_loss: 0.8149 - val_accuracy: 0.6979
# Epoch 18/40
# 108/108 [==============================] - 15s 137ms/step - loss: 0.9095 - accuracy: 0.6591 - val_loss: 0.7855 - val_accuracy: 0.6991
# Epoch 19/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.8803 - accuracy: 0.6649 - val_loss: 0.7837 - val_accuracy: 0.6968
# Epoch 20/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.8891 - accuracy: 0.6655 - val_loss: 0.8375 - val_accuracy: 0.6667
# Epoch 21/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.8883 - accuracy: 0.6649 - val_loss: 0.7803 - val_accuracy: 0.7083
# Epoch 22/40
# 108/108 [==============================] - 15s 137ms/step - loss: 0.8698 - accuracy: 0.6768 - val_loss: 0.7657 - val_accuracy: 0.7106
# Epoch 23/40
# 108/108 [==============================] - 18s 165ms/step - loss: 0.8649 - accuracy: 0.6777 - val_loss: 0.7495 - val_accuracy: 0.7222
# Epoch 24/40
# 108/108 [==============================] - 16s 149ms/step - loss: 0.8390 - accuracy: 0.6800 - val_loss: 0.7109 - val_accuracy: 0.7454
# Epoch 25/40
# 108/108 [==============================] - 16s 147ms/step - loss: 0.8353 - accuracy: 0.6864 - val_loss: 0.7392 - val_accuracy: 0.7407
# Epoch 26/40
# 108/108 [==============================] - 15s 139ms/step - loss: 0.8464 - accuracy: 0.6762 - val_loss: 0.7078 - val_accuracy: 0.7326
# Epoch 27/40
# 108/108 [==============================] - 16s 143ms/step - loss: 0.8322 - accuracy: 0.6872 - val_loss: 0.7002 - val_accuracy: 0.7384
# Epoch 28/40
# 108/108 [==============================] - 15s 141ms/step - loss: 0.8310 - accuracy: 0.6898 - val_loss: 0.7211 - val_accuracy: 0.7338
# Epoch 29/40
# 108/108 [==============================] - 15s 143ms/step - loss: 0.8073 - accuracy: 0.6997 - val_loss: 0.7234 - val_accuracy: 0.7188
# Epoch 30/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.8035 - accuracy: 0.7026 - val_loss: 0.6917 - val_accuracy: 0.7500
# Epoch 31/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.7837 - accuracy: 0.7081 - val_loss: 0.7634 - val_accuracy: 0.7315
# Epoch 32/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.7982 - accuracy: 0.6997 - val_loss: 0.7221 - val_accuracy: 0.7326
# Epoch 33/40
# 108/108 [==============================] - 15s 140ms/step - loss: 0.7934 - accuracy: 0.7150 - val_loss: 0.7354 - val_accuracy: 0.7361
# Epoch 34/40
# 108/108 [==============================] - 15s 140ms/step - loss: 0.7812 - accuracy: 0.7049 - val_loss: 0.6857 - val_accuracy: 0.7477
# Epoch 35/40
# 108/108 [==============================] - 15s 139ms/step - loss: 0.7781 - accuracy: 0.7061 - val_loss: 0.7087 - val_accuracy: 0.7407
# Epoch 36/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.7529 - accuracy: 0.7214 - val_loss: 0.6818 - val_accuracy: 0.7488
# Epoch 37/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.7665 - accuracy: 0.7214 - val_loss: 0.7200 - val_accuracy: 0.7269
# Epoch 38/40
# 108/108 [==============================] - 15s 137ms/step - loss: 0.7482 - accuracy: 0.7139 - val_loss: 0.6793 - val_accuracy: 0.7650
# Epoch 39/40
# 108/108 [==============================] - 16s 144ms/step - loss: 0.7486 - accuracy: 0.7281 - val_loss: 0.6729 - val_accuracy: 0.7546
# Epoch 40/40
# 108/108 [==============================] - 15s 138ms/step - loss: 0.7441 - accuracy: 0.7292 - val_loss: 0.6787 - val_accuracy: 0.7442

# %%
categories = np.sort(os.listdir(folder_dir))
fig, ax = plt.subplots(6,6, figsize=(25, 40))

for i in range(6):
    for j in range(6):
        k = int(np.random.random_sample() * len(X_test))
        if(categories[np.argmax(y_test[k])] == categories[np.argmax(model.predict(X_test)[k])]):
            ax[i,j].set_title("TRUE: " + categories[np.argmax(y_test[k])], color='green')
            ax[i,j].set_xlabel("PREDICTED: " + categories[np.argmax(model.predict(X_test)[k])], color='green')
            ax[i,j].imshow(np.array(X_test)[k].reshape(SIZE, SIZE, 3), cmap='gray')
        else:
            ax[i,j].set_title("TRUE: " + categories[np.argmax(y_test[k])], color='red')
            ax[i,j].set_xlabel("PREDICTED: " + categories[np.argmax(model.predict(X_test)[k])], color='red')
            ax[i,j].imshow(np.array(X_test)[k].reshape(SIZE, SIZE, 3), cmap='gray')
